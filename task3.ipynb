# %% [markdown]
# <a href="https://colab.research.google.com/github/AtharvRai67/task-1/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Import csv file

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d701c94d-efec-42a1-b6e7-67fdccd4a93a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d701c94d-efec-42a1-b6e7-67fdccd4a93a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Day 2: Check shape and column

# %%
print("Shape of dataset:", df.shape) # Check shape (rows, columns)
# Out:
# Shape of dataset: (100, 7)

# %%
print("Columns:", df.columns)        # Check column names
# Out:
# Columns: Index(['Date', 'Product', 'Quantity', 'Price', 'Customer_ID', 'Region',
#        'Total_Sales'],
#       dtype='object')

# %%
# Display first 5 rows
print(df.head())
# Out:
#          Date     Product  Quantity  Price Customer_ID Region  Total_Sales
# 0  2024-01-01       Phone         7  37300     CUST001   East       261100
# 1  2024-01-02  Headphones         4  15406     CUST002  North        61624
# 2  2024-01-03       Phone         2  21746     CUST003   West        43492
# 3  2024-01-04  Headphones         1  30895     CUST004   East        30895
# 4  2024-01-05      Laptop         8  39835     CUST005  North       318680

# %% [markdown]
# Data Types and Detailed info

# %%
print("\nData Types:")
print(df.dtypes)             # Check data types
# Out:
# Data Types:
# Date           object
# Product        object
# Quantity        int64
# Price           int64
# Customer_ID    object
# Region         object
# Total_Sales     int64
# dtype: object

# %%
print("\nDataset Info:")
print(df.info())          # Detailed info
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         100 non-null    object
#  1   Product      100 non-null    object
#  2   Quantity     100 non-null    int64
#  3   Price        100 non-null    int64
#  4   Customer_ID  100 non-null    object
#  5   Region       100 non-null    object
#  6   Total_Sales  100 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 5.6+ KB
# None

# %% [markdown]
# Day 3: Handle missing values and remove duplicates

# %%
# finding missing vale
print("Missing Values:\n")
print(df.isnull().sum())
# Out:
# Missing Values:
#
# Date           0
# Product        0
# Quantity       0
# Price          0
# Customer_ID    0
# Region         0
# Total_Sales    0
# dtype: int64

# %%
# filling missing value
df.fillna(0, inplace=True)
print(df)
# Out:
#           Date     Product  Quantity  Price Customer_ID Region  Total_Sales
# 0   2024-01-01       Phone         7  37300     CUST001   East       261100
# 1   2024-01-02  Headphones         4  15406     CUST002  North        61624
# 2   2024-01-03       Phone         2  21746     CUST003   West        43492
# 3   2024-01-04  Headphones         1  30895     CUST004   East        30895
# 4   2024-01-05      Laptop         8  39835     CUST005  North       318680
# ..         ...         ...       ...    ...         ...    ...          ...
# 95  2024-04-05      Tablet         8  20770     CUST096  North       166160
# 96  2024-04-06  Headphones         1   7647     CUST097   West         7647
# 97  2024-04-07      Tablet         5  27196     CUST098   East       135980
# 98  2024-04-08     Monitor         1  30717     CUST099  North        30717
# 99  2024-04-09  Headphones         5  23376     CUST100  South       116880
#
# [100 rows x 7 columns]

# %%
# Removing duplicates vales
df.drop_duplicates(inplace=True)
print(df)
# Out:
#           Date     Product  Quantity  Price Customer_ID Region  Total_Sales
# 0   2024-01-01       Phone         7  37300     CUST001   East       261100
# 1   2024-01-02  Headphones         4  15406     CUST002  North        61624
# 2   2024-01-03       Phone         2  21746     CUST003   West        43492
# 3   2024-01-04  Headphones         1  30895     CUST004   East        30895
# 4   2024-01-05      Laptop         8  39835     CUST005  North       318680
# ..         ...         ...       ...    ...         ...    ...          ...
# 95  2024-04-05      Tablet         8  20770     CUST096  North       166160
# 96  2024-04-06  Headphones         1   7647     CUST097   West         7647
# 97  2024-04-07      Tablet         5  27196     CUST098   East       135980
# 98  2024-04-08     Monitor         1  30717     CUST099  North        30717
# 99  2024-04-09  Headphones         5  23376     CUST100  South       116880
#
# [100 rows x 7 columns]

# %% [markdown]
# Day 4: Analyze Sales - Calculate revenue, find best product

# %%
# Total Revenue
total_revenue = df['Total_Sales'].sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 12365048

# %%
# Average sale
average_sales = df['Total_Sales'].mean()
print("Average Sales:", average_sales)
# Out:
# Average Sales: 123650.48

# %%
# Highest Sale
highest_sale = df['Total_Sales'].max()
print("Highest Sale:", highest_sale)
# Out:
# Highest Sale: 373932

# %%
#Lowest sale
lowest_sale = df['Total_Sales'].min()
print("lowest sale:" , lowest_sale )
# Out:
# lowest sale: 6540

# %%
#Best-Selling Product (By Revenue)
best_product = df.groupby('Product')['Total_Sales'].sum().idxmax()
print(f"The best-selling product is: {best_product}")
# Out:
# The best-selling product is: Laptop

# %% [markdown]
# Day 5: Create Report - Format output, add insights

# %%
import pandas as pd

# Basic Calculations
total_revenue = df['Total_Sales'].sum()
average_sales = df['Total_Sales'].mean()
highest_sale = df['Total_Sales'].max()
lowest_sale = df['Total_Sales'].min()

# Best selling product (by revenue)
best_product = df.groupby('Product')['Total_Sales'].sum().idxmax()

# Most active region
top_region = df['Region'].value_counts().idxmax()

# Product-wise revenue
product_revenue = df.groupby('Product')['Total_Sales'].sum().sort_values(ascending=False)

print("\n================ SALES ANALYSIS REPORT ================")
print(f"Total Revenue        : ₹{total_revenue:,.2f}")
print(f"Average Sale Value   : ₹{average_sales:,.2f}")
print(f"Highest Sale         : ₹{highest_sale:,.2f}")
print(f"Lowest Sale          : ₹{lowest_sale:,.2f}")
print(f"Best Selling Product : {best_product}")
print(f"Top Performing Region: {top_region}")
print("=======================================================\n")

print("Product-wise Revenue:")
print(product_revenue)

print("\n================ INSIGHTS ================")
print("1. Laptop generates the highest revenue among all products.")
print("2. North region shows the highest number of sales transactions.")
print("3. The sales variation is high, indicating different pricing levels.")
print("4. Average sale value is around ₹1.65 lakh per transaction.")
print("==========================================")
# Out:
# ================ SALES ANALYSIS REPORT ================
# Total Revenue        : ₹12,365,048.00
# Average Sale Value   : ₹123,650.48
# Highest Sale         : ₹373,932.00
# Lowest Sale          : ₹6,540.00
# Best Selling Product : Laptop
# Top Performing Region: North
# ...
#
# Product-wise Revenue:
# Product
# Laptop        3889210
# Tablet        2884340
# Phone         2859394
# Headphones    1384033
# Monitor       1348071
# Name: Total_Sales, dtype: int64
#
# ================ INSIGHTS ================
# 1. Laptop generates the highest revenue among all products.
# 2. North region shows the highest number of sales transactions.
# 3. The sales variation is high, indicating different pricing levels.
# 4. Average sale value is around ₹1.65 lakh per transaction.
# ...
